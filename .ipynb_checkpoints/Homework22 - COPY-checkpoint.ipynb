# %% [markdown]
# # Homework 22 - Webscraping in Python

# %% [markdown]
# **1.	Create a python function to scrape Yelp data for 50 restaurants close to you OR Craigslist for the top 50 items of any topic interesting to you. Think about what data you want to scrape aside from the name and location. You must pick at least three other fields. You can use beautiful soup, selenium, scrapy, and/or splinter as possible.**

# %% [markdown]
# First, I will import the proper libraries and test my desired url. I am placing the url in an f string so that I can programmatically change the zip code later.

# %%
# Load libraries
from bs4 import BeautifulSoup as bs
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from scrapy import Selector
import requests
import pandas as pd

# this is my zip code
my_zip = 63116

# Yelp url
# use f string, so that "my_zip" can be edited for anyone who wants to use function
url=f'https://www.yelp.com/search?find_desc=Restaurants&find_loc={my_zip}'

# get page response 
response = requests.get(url)
response # yay! successful
# Out:
# <Response [200]>

# %% [markdown]
# Then, I will use the Chrome Driver to open up a new browswer, which we'll be able to inspect.

# %%
# executable path for a chrome driver
executable_path = {'executable_path':ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False) # False, so that it opens a browser

# Visit the yelp url in our browser
browser.visit(url)
# Out:
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\artol\.wdm\drivers\chromedriver\win32\98.0.4758.102]

# %%
soup = bs(browser.html, 'html.parser')

# %%
# My zip code
my_zip = 63116
    
# Empty lists to append
names_list = []
location_list = []
review_list = []
rating_list = []
comments_list = []
hours_list = []

# use f string, so that "my_zip" can be edited for anyone who wants to use function
url=f'https://www.yelp.com/search?find_desc=Restaurants&find_loc={my_zip}'

# Retaurant names
divs = soup.find_all("div", class_="businessName__09f24__EYSZE display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY")
for a in divs:
    names = a.find('a', class_='css-1422juy').text
    names_list.append(names)

# Location 
ps = soup.find_all('p', class_='css-1gfe39a')
for span in ps:
    neighborhood = span.find('span', class_='css-1e4fdj9').text
    location_list.append(neighborhood)

# Reviews
revs = soup.find_all("div", class_="attribute__09f24__hqUj7 display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY")
for rev in revs:
    reviews = rev.find('span', class_="reviewCount__09f24__tnBk4 css-1e4fdj9").text
    review_list.append(reviews)

# Restaurant rating
star_block = soup.find_all("div", class_="attribute__09f24__hqUj7 display--inline-block__09f24__fEDiJ margin-r1__09f24__rN_ga border-color--default__09f24__NPAKY")
for stars in star_block:
    for star in stars:
        rating = star.div['aria-label']
        rating_list.append(rating)

# Open or closed
div = soup.find_all("div", {"class": "display--inline-block__09f24__fEDiJ margin-t1__09f24__w96jn border-color--default__09f24__NPAKY"})
for d in div:
    hour = d.div.span.text
    if hour != '':
        hours_list.append(hour)

# # Create Data frame
# dictionary = {'Retaurant':names_list,
#              'Neighborhood':location_list,
#              'Total Reviews':review_list,
#              'Rating':rating_list}

# df = pd.DataFrame.from_dict(dictionary)
# df.head()

# %%
# Create Data frame
dictionary = {'Retaurant':names_list,
             'Neighborhood':location_list,
             'Total Reviews':review_list,
             'Rating':rating_list}

df = pd.DataFrame.from_dict(dictionary)
df.head(30)
# Out:
#                       Retaurant       Neighborhood Total Reviews  \
# 0             The Drawing Board  Tower Grove South            14
# 1            The Golden Hoosier                 $$            63
# 2                Polite Society   Lafayette Square           803
# 3                     58hundred   Southwest Garden           168
# 4                      Pit Stop           The Hill            70
# 5                    Little Fox           Fox Park            69
# 6                   Stacked STL              Patch           720
# 7               Kounter Kulture    Lindenwood Park           329
# 8   Peacemaker Lobster and Crab        Benton Park           836
# 9                   Olive + Oak                $$$           737
# 10            The Drawing Board  Tower Grove South            14
# 11           The Golden Hoosier                 $$            63
# 12               Polite Society   Lafayette Square           803
# 13                    58hundred   Southwest Garden           168
# 14                     Pit Stop           The Hill            70
# 15                   Little Fox           Fox Park            69
# 16                  Stacked STL              Patch           720
# 17              Kounter Kulture    Lindenwood Park           329
# 18  Peacemaker Lobster and Crab        Benton Park           836
# 19                  Olive + Oak                $$$           737
# 20            The Drawing Board  Tower Grove South            14
# 21           The Golden Hoosier                 $$            63
# 22               Polite Society   Lafayette Square           803
# 23                    58hundred   Southwest Garden           168
# 24                     Pit Stop           The Hill            70
# 25                   Little Fox           Fox Park            69
# 26                  Stacked STL              Patch           720
# 27              Kounter Kulture    Lindenwood Park           329
# 28  Peacemaker Lobster and Crab        Benton Park           836
# 29                  Olive + Oak                $$$           737
#
#              Rating
# 0     5 star rating
# 1   4.5 star rating
# 2   4.5 star rating
# 3   4.5 star rating
# 4     5 star rating
# 5   4.5 star rating
# 6   4.5 star rating
# 7     5 star rating
# 8     4 star rating
# 9   4.5 star rating
# 10    5 star rating
# 11  4.5 star rating
# 12  4.5 star rating
# 13  4.5 star rating
# 14    5 star rating
# 15  4.5 star rating
# 16  4.5 star rating
# 17    5 star rating
# 18    4 star rating
# 19  4.5 star rating
# 20    5 star rating
# 21  4.5 star rating
# 22  4.5 star rating
# 23  4.5 star rating
# 24    5 star rating
# 25  4.5 star rating
# 26  4.5 star rating
# 27    5 star rating
# 28    4 star rating
# 29  4.5 star rating

# %%
print(names_list)
# Out:
# ['Basil India', 'Jack in the Box', 'The Drawing Board', 'The Golden Hoosier', 'Polite Society', '58hundred', 'Pit Stop', 'Little Fox', 'Stacked STL', 'Kounter Kulture', 'Peacemaker Lobster and Crab', 'Olive + Oak', 'Namaste Restaurant And Bar']

# %%
print(location_list)
# Out:
# ['Tower Grove South', 'South Hampton', 'Tower Grove South', '$$', 'Lafayette Square', 'Southwest Garden', 'The Hill', 'Fox Park', 'Patch', 'Lindenwood Park', 'Benton Park', '$$$', 'Saint Louis Hills']

# %%
print(review_list)
# Out:
# ['26', '14', '63', '803', '168', '70', '69', '720', '329', '836', '737', '19']

# %%
print(rating_list)
# Out:
# ['4.5 star rating', '5 star rating', '4.5 star rating', '4.5 star rating', '4.5 star rating', '5 star rating', '4.5 star rating', '4.5 star rating', '5 star rating', '4 star rating', '4.5 star rating', '4 star rating']

# %%
print(hours_list)
# Out:
# ['Closed', 'Open all day', 'Open', 'Open', 'Closed', 'Closes in 5 min', 'Closes in 5 min', 'Closes in 5 min', 'Closed', 'Closes in 35 min', 'Open', 'Closed']

# %%
# Empty lists to append
names_list = []
location_list = []
review_list = []
rating_list = []
comments_list = []
hours_list = []

my_zip = 63116
url=f'https://www.yelp.com/search?find_desc=Restaurants&find_loc={my_zip}'

for next_ in range(10,60,10):
    # get url
    url_next = url + f'&start={next_}'
    
    # executable path for a chrome driver
    executable_path = {'executable_path':ChromeDriverManager().install()}
    browser = Browser('chrome', **executable_path, headless=True) # False, so that it opens a browser

    # Visit the yelp url in our browser
    browser.visit(url_next)
     
    soup = bs(browser.html, 'html.parser')
    
    # Retaurant names
    divs = soup.find_all("div", class_="businessName__09f24__EYSZE display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY")
    for a in divs:
        names = a.find('a', class_='css-1422juy').text
        names_list.append(names)

    # Location 
    ps = soup.find_all('p', class_='css-1gfe39a')
    for span in ps:
        neighborhood = span.find('span', class_='css-1e4fdj9').text
        location_list.append(neighborhood)

    # Reviews
    revs = soup.find_all("div", class_="attribute__09f24__hqUj7 display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY")
    for rev in revs:
        reviews = rev.find('span', class_="reviewCount__09f24__tnBk4 css-1e4fdj9").text
        review_list.append(reviews)

    # Restaurant rating
    star_block = soup.find_all("div", class_="attribute__09f24__hqUj7 display--inline-block__09f24__fEDiJ margin-r1__09f24__rN_ga border-color--default__09f24__NPAKY")
    for stars in star_block:
        for star in stars:
            rating = star.div['aria-label']
            rating_list.append(rating)

    # Open or closed
    div = soup.find_all("div", {"class": "display--inline-block__09f24__fEDiJ margin-t1__09f24__w96jn border-color--default__09f24__NPAKY"})
    for d in div:
        hour = d.div.span.text
        if hour != '':
            hours_list.append(hour)
# Out:
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\artol\.wdm\drivers\chromedriver\win32\98.0.4758.102]
#
#
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\artol\.wdm\drivers\chromedriver\win32\98.0.4758.102]
#
#
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\artol\.wdm\drivers\chromedriver\win32\98.0.4758.102]
#
#
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\artol\.wdm\drivers\chromedriver\win32\98.0.4758.102]
#
#
# ====== WebDriver manager ======
# Could not get version for google-chrome with the command:  powershell "$ErrorActionPreference='silentlycontinue' ; (Get-Item -Path "$env:PROGRAMFILES\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion ; if (-not $? -or $? -match $error) { (Get-Item -Path "$env:PROGRAMFILES(x86)\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { (Get-Item -Path "$env:LOCALAPPDATA\Google\Chrome\Application\chrome.exe").VersionInfo.FileVersion } if (-not $? -or $? -match $error) { reg query "HKCU\SOFTWARE\Google\Chrome\BLBeacon" /v version } if (-not $? -or $? -match $error) { reg query "HKLM\SOFTWARE\Wow6432Node\Microsoft\Windows\CurrentVersion\Uninstall\Google Chrome" /v version }"
# Current google-chrome version is UNKNOWN
# Get LATEST chromedriver version for UNKNOWN google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\artol\.wdm\drivers\chromedriver\win32\98.0.4758.102]

# %%
# browser = browser.links.find_by_partial_href(url_next).click()   
# browser
# #soup = bs(browser.html, 'html.parser')

# %%
print(len(names_list))
print(len(location_list))
print(len(review_list))
print(len(rating_list))
print(len(hours_list))
# Out:
# 50
# 50
# 50
# 50
# 47

# %% [markdown]
# # Clicking to next page

# %%
for next_ in range(10,50,10):
    url_next = url + f'&start={next_}'
    print(url_next)
# Out:
# https://www.yelp.com/search?find_desc=Restaurants&find_loc=63116&start=10
# https://www.yelp.com/search?find_desc=Restaurants&find_loc=63116&start=20
# https://www.yelp.com/search?find_desc=Restaurants&find_loc=63116&start=30
# https://www.yelp.com/search?find_desc=Restaurants&find_loc=63116&start=40

# %% [markdown]
# # Testing functions

# %%
# First page - starter url
def yelp_search():
    
    my_zip = input('Enter Your Zip Code')
    my_zip = int(my_zip)
    
    # Empty lists to append
    names_list = []
    location_list = []
    review_list = []
    rating_list = []
    comments_list = []
    hours_list = []
    dictionary = {}
    
    # use f string, so that "my_zip" can be edited for anyone who wants to use function
    url=f'https://www.yelp.com/search?find_desc=Restaurants&find_loc={my_zip}'
    
    # executable path for a chrome driver
    executable_path = {'executable_path':ChromeDriverManager().install()}
    browser = Browser('chrome', **executable_path, headless=True) # Don't open browser with function

    # Visit the yelp url in our browser
    browser.visit(url)
    
    # Parse the browser
    soup = bs(browser.html, 'html.parser')
    
    # inner function
    def restaurant_search():
        # Retaurant names
        divs = soup.find_all("div", class_="businessName__09f24__EYSZE display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY")
        for a in divs:
            names = a.find('a', class_='css-1422juy').text
            names_list.append(names)
            dictionary['Restaurant'] = names_list

        # Location 
        ps = soup.find_all('p', class_='css-1gfe39a')
        for span in ps:
            neighborhood = span.find('span', class_='css-1e4fdj9').text
            location_list.append(neighborhood)
            dictionary['Neighborhood'] = location_list

        # Reviews
        revs = soup.find_all("div", class_="attribute__09f24__hqUj7 display--inline-block__09f24__fEDiJ border-color--default__09f24__NPAKY")
        for rev in revs:
            reviews = rev.find('span', class_="reviewCount__09f24__tnBk4 css-1e4fdj9").text
            review_list.append(reviews)
            dictionary['Total Reviews'] = review_list

        # Restaurant rating
        star_block = soup.find_all("div", class_="attribute__09f24__hqUj7 display--inline-block__09f24__fEDiJ margin-r1__09f24__rN_ga border-color--default__09f24__NPAKY")
        for stars in star_block:
            for star in stars:
                rating = star.div['aria-label']
                rating_list.append(rating)
                dictionary['Ratings'] = rating_list

        # Open or closed
        div = soup.find_all("div", {"class": "display--inline-block__09f24__fEDiJ margin-t1__09f24__w96jn border-color--default__09f24__NPAKY"})
        for d in div:
            hour = d.div.span.text
            if hour != '':
                hours_list.append(hour)
                dictionary['Open or Closed'] = hours_list




#         # Create Data frame
#         dictionary = {'Retaurant':names_list,
#                      'Neighborhood':location_list,
#                      'Total Reviews':review_list,
#                      'Rating':rating_list,
#                      'Open or Closed':hours_list}

                df = pd.DataFrame.from_dict(dictionary)
                return df

# %% [markdown]
# **2. Create a local API that calls your scrape function and stores the data when you call /scrape endpoint. The data you scrape should be viewable when you go to /all.**

# %% [markdown]
# **3. What is web scraping? Why is it helpful? What does it mean for your online presence? Refence the readings and DataCamp.**
